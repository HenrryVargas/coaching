# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.decomposition import PCA
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df= pd.read_csv('DatosDemograficos.csv')

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

# In general, it's a good idea to scale the data prior to PCA.
scaler = StandardScaler()
scaler.fit(X)
X=scaler.transform(X)    
pca = PCA()
x_new = pca.fit_transform(X)

# %%
def myplot(score,coeff,labels=None):
    xs = score[:,0]
    ys = score[:,1]
    n = coeff.shape[0]
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())
    plt.scatter(xs * scalex,ys * scaley, c = y)
    for i in range(n):
        plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
        if labels is None:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'g', ha = 'center', va = 'center')
        else:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, labels[i], color = 'g', ha = 'center', va = 'center')
    plt.xlim(-1,1)
    plt.ylim(-1,0.6)
    plt.xlabel("PC{}".format(1))
    plt.ylabel("PC{}".format(2))
    plt.grid()

# %%
pca.components_[0:2, :]
# Out:
# array([[ 0.52106591, -0.26934744,  0.5804131 ,  0.56485654],
#        [ 0.37741762,  0.92329566,  0.02449161,  0.06694199]])

# %%
pca.components_
# Out:
# array([[ 0.52106591, -0.26934744,  0.5804131 ,  0.56485654],
#        [ 0.37741762,  0.92329566,  0.02449161,  0.06694199],
#        [-0.71956635,  0.24438178,  0.14212637,  0.63427274],
#        [-0.26128628,  0.12350962,  0.80144925, -0.52359713]])

# %%
#Call the function. Use only the 2 PCs.
myplot(x_new[:,0:2],np.transpose(pca.components_[0:2, :]))
plt.show()

# %%
 import numpy as np 
 nb_classes = 6 
 data = [[2, 3, 4, 0]] 
 def indices_to_one_hot(data, nb_classes): 
     """Convert an iterable of indices to one-hot encoded labels.""" 
     targets = np.array(data).reshape(-1) 
     return np.eye(nb_classes)[targets]

# %%
 def one_hot_to_indices(data): 
     indices = [] 
     for el in data: 
         indices.append(list(el).index(1)) 
     return indices 
 hot = indices_to_one_hot(X, nb_classes) 
 indices = one_hot_to_indices(hot) 
 print(X) 
 print(indices)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-5308892da567> in <module>
#       4         indices.append(list(el).index(1))
#       5     return indices
# ----> 6 hot = indices_to_one_hot(X, nb_classes)
#       7 indices = one_hot_to_indices(hot)
#       8 print(X)
#
# <ipython-input-25-f838fc5dc0ab> in indices_to_one_hot(data, nb_classes)
#       5     """Convert an iterable of indices to one-hot encoded labels."""
#       6     targets = np.array(data).reshape(-1)
# ----> 7     return np.eye(nb_classes)[targets]
#
# IndexError: arrays used as indices must be of integer (or boolean) type
